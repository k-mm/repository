# %%
# !pip install pandas_datareader

# %%
from pandas_datareader import data
import pandas as pd
import matplotlib.pyplot as plt
import numpy  as np
# %matplotlib inline

# %%
start = '2019-06-01'
end = '2020-06-01'

df = data.DataReader('^N225', 'yahoo', start, end)

# %%
df.head(10)
# Out:
#                     High           Low          Open         Close    Volume  \
# Date
# 2019-06-03  20438.029297  20305.740234  20327.869141  20410.880859  67400000
# 2019-06-04  20464.570312  20289.640625  20435.859375  20408.539062  69200000
# 2019-06-05  20800.640625  20646.150391  20667.890625  20776.099609  72300000
# 2019-06-06  20842.279297  20745.839844  20745.839844  20774.039062  59600000
# 2019-06-07  20907.769531  20816.580078  20859.779297  20884.710938  50700000
# 2019-06-10  21166.119141  21077.949219  21095.400391  21134.419922  58200000
# 2019-06-11  21227.179688  21066.619141  21099.539062  21204.279297  52100000
# 2019-06-12  21259.699219  21118.750000  21130.390625  21129.720703  56500000
# 2019-06-13  21111.230469  20932.130859  21040.910156  21032.000000  65700000
# 2019-06-14  21119.730469  20971.179688  21049.410156  21116.890625  60400000
#
#                Adj Close
# Date
# 2019-06-03  20410.880859
# 2019-06-04  20408.539062
# 2019-06-05  20776.099609
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2019-06-03', '2019-06-04', '2019-06-05', '2019-06-06',
#                '2019-06-07', '2019-06-10', '2019-06-11', '2019-06-12',
#                '2019-06-13', '2019-06-14',
#                ...
#                '2020-05-19', '2020-05-20', '2020-05-21', '2020-05-22',
#                '2020-05-25', '2020-05-26', '2020-05-27', '2020-05-28',
#                '2020-05-29', '2020-06-01'],
#               dtype='datetime64[ns]', name='Date', length=242, freq=None)

# %%
date = df.index
price = df['Adj Close']

# %%
plt.plot(date, price)

# %%
plt.figure(figsize=(30,10))
plt.plot(date, price, label='Nikkei225', color='#99b898')
plt.plot(date, df['sma01'], label='sma01', color='#e84a5f')
plt.plot(date, df['sma02'], label='sma02', color='#ff847c')
plt.plot(date, df['sma03'], label='sma03', color='#feceab')


plt.title('N225', color='blue', backgroundcolor='white', size=40, loc='center')
plt.xlabel('date', color='black', size=30)
plt.ylabel('price', color='black', size=30)

plt.legend()

# %% [markdown]
# ### 単純移動平均を追加

# %%
span01 = 5
span02 = 25
span03 = 30

df['sma01'] = price.rolling(window=span01).mean()
df['sma02'] = price.rolling(window=span02).mean()
df['sma03'] = price.rolling(window=span03).mean()

# %%
pd.set_option('display.max_rows', None)
df.head(100)
# Out:
#                     High           Low          Open         Close     Volume  \
# Date
# 2019-06-03  20438.029297  20305.740234  20327.869141  20410.880859   67400000
# 2019-06-04  20464.570312  20289.640625  20435.859375  20408.539062   69200000
# 2019-06-05  20800.640625  20646.150391  20667.890625  20776.099609   72300000
# 2019-06-06  20842.279297  20745.839844  20745.839844  20774.039062   59600000
# 2019-06-07  20907.769531  20816.580078  20859.779297  20884.710938   50700000
# 2019-06-10  21166.119141  21077.949219  21095.400391  21134.419922   58200000
# 2019-06-11  21227.179688  21066.619141  21099.539062  21204.279297   52100000
# 2019-06-12  21259.699219  21118.750000  21130.390625  21129.720703   56500000
# 2019-06-13  21111.230469  20932.130859  21040.910156  21032.000000   65700000
# 2019-06-14  21119.730469  20971.179688  21049.410156  21116.890625   60400000
# 2019-06-17  21185.250000  21044.619141  21094.960938  21124.000000   49100000
# ...

# %% [markdown]
# ### 棒グラフの作成

# %%
plt.figure(figsize=(30,15))
plt.bar(date, df['Volume'], label='Volume', color='gray')

plt.legend()

# %%
plt.figure(figsize=(30, 15))
plt.subplot(2,1,1)

plt.plot(date, price, label='Close', color='#99b898')
plt.plot(date, df['sma01'], label='sma01', color='#e84a5f')
plt.plot(date, df['sma02'], label='sma02', color='#ff847c')
plt.plot(date, df['sma03'], label='sma03', color='#feceab')
plt.legend()

plt.subplot(2,1,2)
plt.bar(date, df['Volume'], label='Volume', color='gray')
plt.legend()

# %% [markdown]
# ### 個別銘柄の取得

# %% [markdown]
# リクルートホールディングス(証券コード：6908)

# %%
type(data)
# Out:
# module

# %%
df = data.DataReader('6908.JP', 'stooq')

# %%
df.head(3)
# Out:
#               Open    High     Low   Close  Volume
# Date
# 2022-06-27  3265.0  3265.0  3175.0  3195.0   59500
# 2022-06-24  3215.0  3275.0  3215.0  3225.0   72000
# 2022-06-23  3130.0  3210.0  3115.0  3145.0   39400

# %%
df.index.min()
# Out:
# Timestamp('2017-06-29 00:00:00')

# %%
df.index.max()
# Out:
# Timestamp('2022-06-27 00:00:00')

# %%
df.tail(3)
# Out:
#                Open     High      Low    Close  Volume
# Date
# 2017-07-03  4193.30  4231.04  4094.25  4146.14  296807
# 2017-06-30  4198.02  4278.21  4179.15  4264.05  107486
# 2017-06-29  4273.50  4301.78  4254.63  4282.93   75686

# %% [markdown]
# データフレームのインデックスの並び替え

# %%
df = df.sort_index()
df.head(3)
# Out:
#                Open     High      Low    Close  Volume
# Date
# 2017-06-29  4273.50  4301.78  4254.63  4282.93   75686
# 2017-06-30  4198.02  4278.21  4179.15  4264.05  107486
# 2017-07-03  4193.30  4231.04  4094.25  4146.14  296807

# %%
df[df.index>='2019-06-01 00:00:00'].head()
# Out:
#                Open     High      Low    Close  Volume
# Date
# 2019-06-03  4581.58  4634.09  4471.81  4519.53  137979
# 2019-06-04  4519.53  4839.30  4519.53  4810.66  151809
# 2019-06-05  4906.11  5020.65  4896.56  4925.20   62022
# 2019-06-06  4953.83  4972.92  4896.56  4925.20   56050
# 2019-06-07  5058.84  5068.38  4925.20  4944.29   81928

# %%
df[df.index<='2020-05-01 00:00:00'].head()
# Out:
#                Open     High      Low    Close  Volume
# Date
# 2019-06-03  4581.58  4634.09  4471.81  4519.53  137979
# 2019-06-04  4519.53  4839.30  4519.53  4810.66  151809
# 2019-06-05  4906.11  5020.65  4896.56  4925.20   62022
# 2019-06-06  4953.83  4972.92  4896.56  4925.20   56050
# 2019-06-07  5058.84  5068.38  4925.20  4944.29   81928

# %%
df = df[(df.index>='2019-06-01 00:00:00') & (df.index<='2020-05-01 00:00:00')]

# %% [markdown]
# 可視化

# %%
date = df.index
price = df['Close']

span01 = 5
span02 = 25
span03 = 50

df['sma01'] = price.rolling(window=span01).mean()
df['sma02'] = price.rolling(window=span02).mean()
df['sma03'] = price.rolling(window=span03).mean()

plt.figure(figsize=(30,15))
plt.subplot(2,1,1)

plt.plot(date, price, label='Close', color='#000000')
plt.plot(date, df['sma01'], label='sma01', color='#B3424A')
plt.plot(date, df['sma02'], label='sma02', color='#F8B400')
plt.plot(date, df['sma03'], label='sma03', color='#9ACD32')
plt.legend()


plt.subplot(2,1,2)

plt.bar(date, df['Volume'], label='volume', color='#808080')
plt.legend()

# %% [markdown]
# ファーストリテイリング(証券コード：9983)

# %%
start = '2019-06-01'
end = '2020-05-01'
company_code = '9983.JP'

# %%
df = data.DataReader(company_code, 'stooq')
df = df[(df.index>=start) & (df.index<=end)]

date = df.index
price = df['Close']

span01 = 5
span02 = 25
span03 = 50

df['sma01'] = price.rolling(window=span01).mean()
df['sma02'] = price.rolling(window=span02).mean()
df['sma03'] = price.rolling(window=span03).mean()

plt.figure(figsize=(30,15))
plt.subplot(2,1,1)

plt.plot(date, price, label='Close', color='#000000')
plt.plot(date, df['sma01'], label='sma01', color='#B3424A')
plt.plot(date, df['sma02'], label='sma02', color='#F8B400')
plt.plot(date, df['sma03'], label='sma03', color='#9ACD32')
plt.legend()


plt.subplot(2,1,2)

plt.bar(date, df['Volume'], label='volume', color='#808080')
plt.legend()

# %% [markdown]
# 上記の流れを関数化する

# %%
def company_stock(start,end,company_code):
    df = data.DataReader(company_code, 'stooq')
    df = df[(df.index>=start) & (df.index<=end)]

    date = df.index
    price = df['Close']

    span01 = 5
    span02 = 25
    span03 = 50

    df['sma01'] = price.rolling(window=span01).mean()
    df['sma02'] = price.rolling(window=span02).mean()
    df['sma03'] = price.rolling(window=span03).mean()

    plt.figure(figsize=(30,15))
    plt.subplot(2,1,1)

    plt.plot(date, price, label='Close', color='#000000')
    plt.plot(date, df['sma01'], label='sma01', color='#B3424A')
    plt.plot(date, df['sma02'], label='sma02', color='#F8B400')
    plt.plot(date, df['sma03'], label='sma03', color='#9ACD32')
    plt.legend()


    plt.subplot(2,1,2)

    plt.bar(date, df['Volume'], label='volume', color='#808080')
    plt.legend()

# %% [markdown]
# 関数の実行（ソニー：6758）

# %%
company_stock('2019-06-01', '2020-06-01','6758.JP')

# %% [markdown]
# トヨタ(7203)

# %%
company_stock('2019-06-01', '2020-06-01','7203.JP')

# %%
company_stock('2019-06-01', '2022-06-01','TSLA.US')

# %%
company_stock('2019-06-01', '2022-06-01','ACN.US')

# %%
company_stock('2019-06-01', '2022-06-01','RIVN.US')

# %%
company_stock('2019-06-01', '2022-06-01','BAC.US')

# %%
company_stock('2019-06-01', '2022-06-01','GLD.US')

# %%
company_stock('2019-06-01', '2022-06-01','SLV.US')
